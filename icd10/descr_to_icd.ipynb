# %%
import pandas as pd

# %%
df = pd.read_table("tls_Icd10cmHumanReadableMap_US1000124_20180301.tsv")
df = df.loc[:, 'mapTarget':'mapTargetName']
df = df.drop_duplicates()
# Out:
#        mapTarget                                      mapTargetName
# 0          R07.9                            Chest pain, unspecified
# 1          P36.9           Bacterial sepsis of newborn, unspecified
# 2          A41.9                       Sepsis, unspecified organism
# 3          Q04.8  Other specified congenital malformations of brain
# 4         I26.99  Other pulmonary embolism without acute cor pul...
# 5            NaN                                                NaN
# 6          K03.0                       Excessive attrition of teeth
# 7         N42.89              Other specified disorders of prostate
# 8        M62.830                               Muscle spasm of back
# 9          I31.8            Other specified diseases of pericardium
# 10       F13.930  Sedative, hypnotic or anxiolytic use, unspecif...
# 11         Z60.5  Target of (perceived) adverse discrimination a...
# 12         Q79.6                             Ehlers-Danlos syndrome
# ...
