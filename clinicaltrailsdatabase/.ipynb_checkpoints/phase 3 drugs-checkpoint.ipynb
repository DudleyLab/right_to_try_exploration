# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("phase3.csv" , sep=",", error_bad_lines=False)

# %%
df.head(50)
# Out:
#     Rank   NCT Number                                              Title  \
# 0      1  NCT03573908  A Trial of Linaclotide 290 μg in Patients With...
# 1      2  NCT03573882  Study to Assess the Effect of Long-term Treatm...
# 2      3  NCT03573817  A 42-day Parallel Group Safety Study of Revefe...
# 3      4  NCT03573401  A Randomized, Double Blind, Vehicle-controlled...
# 4      5  NCT03573297  A Cariprazine Study in the Prevention of Relap...
# 5      6  NCT03572933  Study of Adjunctive Ganaxolone Treatment in Ch...
# 6      7  NCT03571737  Efficacy of Lidocaine Patch in Acute Musculosk...
# 7      8  NCT03571672     Better Accuracy in EF Assessment With DEFINITY
# 8      9  NCT03571607  A Safety And Immunogenicity Study Of A 13-vale...
# 9     10  NCT03571516  Safety, Efficacy and Pharmacokinetic Study of ...
# 10    11  NCT03571256  A Study to Test if TEV-50717 is Effective in R...
# 11    12  NCT03571126  Olanzapine for the Prevention and Treatment of...
# ...

# %%
interventions = df['Interventions'].dropna()
drugs=[]

for intervention in interventions:
    if((intervention[0:5] == "Drug:") and (intervention not in drugs)):
        drugs.append(intervention)
print(len(drugs))
# Out:
# 4565

# %%
for drug in drugs:
    print(drug)
# Out:
# Drug: Linaclotide|Drug: Placebo
# Drug: Voxelotor
# Drug: revefenacin|Drug: Placebo|Drug: Formoterol
# Drug: Cariprazine|Drug: Placebo
# Drug: ganaxolone|Drug: Placebo
# Drug: Ibuprofen|Drug: Lidocaine Patch 4%
# Drug: DEFINITY
# Drug: Teduglutide|Other: Standard Medical Therapy|Device: Syringe|Device: Needle
# Drug: deutetrabenazine Low|Drug: deutetrabenazine High|Drug: Placebo
# Drug: Olanzapine|Drug: Placebos
# Drug: Tisagenlecleucel after optional bridging and lymphodepleting chemotherapy|Drug: Platinum-based immunochemotherapy followed in responding patients with high dose chemotherapy and HSCT
# Drug: Levomilnacipran ER|Drug: Fluoxetine|Drug: Placebo
# Drug: Upadacitinib|Drug: Placebo for Upadacitinib
# Drug: Larazotide Acetate|Drug: Matching Placebo
# Drug: Transdermal Estrogen
# Drug: Delamanid (DLM)|Drug: Isoniazid (INH)|Dietary Supplement: Pyridoxine (vitamin B6)
# Drug: Tradipitant|Drug: Placebo
# ...

# %%
with open("expanded_acess_avilable+marketing.txt", 'w') as file_handler:
    for drug in drugs:
        file_handler.write("{}\n".format(drug))
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-8-e97d797d8932> in <module>()
#       1 with open("expanded_acess_avilable+marketing.txt", 'w') as file_handler:
#       2     for drug in drugs:
# ----> 3         file_handler.write("{}\n".format(drug))
#
# c:\users\ross\appdata\local\conda\conda\envs\fastai\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\uff08' in position 30: character maps to <undefined>
